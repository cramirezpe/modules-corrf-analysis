# %%
from CoLoRe_corrf_analysis.file_funcs import FileFuncs
from pathlib import Path

# %%
basedir = Path('/global/cscratch1/sd/cramirez/NBodyKit/multibias2/')

# %%
for crosspath in basedir.iterdir():
    if crosspath.name[0] == 's':
        print(crosspath.name)
        print(FileFuncs.get_available_runs(crosspath, show_incompleted=True))
# Out:
# s5
# /global/cscratch1/sd/cramirez/NBodyKit/multibias2/s5/nside_2/rsd/0.1_200_41/0.5_0.7/2000/44
# /global/cscratch1/sd/cramirez/NBodyKit/multibias2/s5/nside_2/rsd/0.1_200_41/0.5_0.7/2000/27
# /global/cscratch1/sd/cramirez/NBodyKit/multibias2/s5/nside_2/rsd/0.1_200_41/0.5_0.7/2000/1
# /global/cscratch1/sd/cramirez/NBodyKit/multibias2/s5/nside_2/rsd/0.1_200_41/0.5_0.7/2000/45
# /global/cscratch1/sd/cramirez/NBodyKit/multibias2/s5/nside_2/rsd/0.1_200_41/0.5_0.7/2000/0
# /global/cscratch1/sd/cramirez/NBodyKit/multibias2/s5/nside_2/rsd/0.1_200_41/0.5_0.7/2000/25
# /global/cscratch1/sd/cramirez/NBodyKit/multibias2/s5/nside_2/rsd/0.1_200_41/0.5_0.7/2000/10
# /global/cscratch1/sd/cramirez/NBodyKit/multibias2/s5/nside_2/rsd/0.1_200_41/0.5_0.7/2000/3
# /global/cscratch1/sd/cramirez/NBodyKit/multibias2/s5/nside_2/rsd/0.1_200_41/0.5_0.7/2000/20
# /global/cscratch1/sd/cramirez/NBodyKit/multibias2/s5/nside_2/rsd/0.1_200_41/0.5_0.7/2000/21
# ...
